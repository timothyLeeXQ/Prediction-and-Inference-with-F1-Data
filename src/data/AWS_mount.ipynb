# %% [markdown]
# # Code for AWS Mount

# %%
ACCESS_KEY = ''
# Encode the Secret Key as that can contain '/'
SECRET_KEY = ''.replace("/", "%2F")
AWS_BUCKET_NAME_RAW = 'ne-gr5069'
MOUNT_NAME_RAW = 'ne-gr5069'
AWS_BUCKET_NAME_PROC = 'xql2001-gr5069'
MOUNT_NAME_PROC = 'xql2001-gr5069'

# %%
dbutils.fs.mount('s3a://%s:%s@%s' % (ACCESS_KEY, SECRET_KEY, AWS_BUCKET_NAME_RAW),
                 '/mnt/%s' % MOUNT_NAME_RAW)
display(dbutils.fs.ls('/mnt/%s' % MOUNT_NAME_RAW))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-4354284095255629&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> dbutils.fs.mount(&#39;s3a://%s:%s@%s&#39; % (ACCESS_KEY, SECRET_KEY, AWS_BUCKET_NAME_RAW),
# </span><span class="ansi-green-intense-fg ansi-bold">      2</span>                  &#39;/mnt/%s&#39; % MOUNT_NAME_RAW)
# <span class="ansi-green-intense-fg ansi-bold">      3</span> display<span class="ansi-blue-fg">(</span>dbutils<span class="ansi-blue-fg">.</span>fs<span class="ansi-blue-fg">.</span>ls<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;/mnt/%s&#39;</span> <span class="ansi-blue-fg">%</span> MOUNT_NAME_RAW<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">NameError</span>: name &#39;ACCESS_KEY&#39; is not defined</div>

# %%
dbutils.fs.mount('s3a://%s:%s@%s' % (ACCESS_KEY, SECRET_KEY, AWS_BUCKET_NAME_PROC),
                 '/mnt/%s' % MOUNT_NAME_PROC)
display(dbutils.fs.ls('/mnt/%s' % MOUNT_NAME_PROC))
